# %% [markdown]
# # Dataset preprocessing

# %% [markdown]
# ## Training dataset

# %% [markdown]
# #### Importing necessary libraries

# %%
import pandas as pd
import re
import copy
import time
from deep_translator import GoogleTranslator

# %% [markdown]
# #### Reading the training dataset

# %%
df = pd.read_excel('training.xlsx')
df.head()
# Out:
#   userGender  category                                            comment
# 0       MALE         2  Balita nyu na si liza marcos at mga ksma nya s...
# 1     FEMALE         2     babalik ka rin... babalik at babalik karin💪👊👊👊
# 2       MALE         1                      Bi Tay ✈️  (i mean bye Tay👋🏼)
# 3       MALE         2  Justice system ng pilipinas ay palpak kaya nam...
# 4       MALE         2  If only the victims of martial law had the sam...

# %% [markdown]
# #### Removing emojis and translating the comments to english

# %%
# Emoji removal regex (compiled once)
EMOJI_REGEX = re.compile(
    "["
    "\U0001F600-\U0001F64F"
    "\U0001F300-\U0001F5FF"
    "\U0001F680-\U0001F6FF"
    "\U0001F1E0-\U0001F1FF"
    "\U00002700-\U000027BF"
    "\U0001F900-\U0001F9FF"
    "\U0001FA70-\U0001FAFF"
    "\U00002600-\U000026FF"
    "]+", flags=re.UNICODE
)

# Helper to remove emojis
def remove_emojis(text):
    return EMOJI_REGEX.sub('', text)

translator = GoogleTranslator(source="auto", target="en")
commentsTranslation = []

for i, comment in enumerate(df["comment"], start=1):
    comment = remove_emojis(str(comment)) if isinstance(comment, str) else ""
    translated = ""

    for attempt in range(5):
        try:
            if comment:
                translated = translator.translate(comment)
                print(f"Comment {i} translated successfully.")
            break
        except Exception as e:
            print(f"Translation failed for comment {i} (attempt {attempt + 1}): {e}")
            time.sleep(3)

    if not translated:
        print(f"Translation failed for comment {i} after maximum retries.")

    commentsTranslation.append(translated)

df["commentsTranslation"] = commentsTranslation
# Out:
# Comment 1 translated successfully.
# Comment 2 translated successfully.
# Comment 3 translated successfully.
# Comment 4 translated successfully.
# Comment 5 translated successfully.
# Comment 6 translated successfully.
# Comment 7 translated successfully.
# Comment 8 translated successfully.
# Translation failed for comment 9 after maximum retries.
# Comment 10 translated successfully.
# Comment 11 translated successfully.
# Comment 12 translated successfully.
# Comment 13 translated successfully.
# Comment 14 translated successfully.
# Comment 15 translated successfully.
# Comment 16 translated successfully.
# Comment 17 translated successfully.
# Comment 18 translated successfully.
# Comment 19 translated successfully.
# Comment 20 translated successfully.
# Comment 21 translated successfully.
# Comment 22 translated successfully.
# Comment 23 translated successfully.
# Comment 24 translated successfully.
# Comment 25 translated successfully.
# Comment 26 translated successfully.
# Comment 27 translated successfully.
# Comment 28 translated successfully.
# Comment 29 translated successfully.
# Comment 30 translated successfully.
# Comment 31 translated successfully.
# Comment 32 translated successfully.
# Comment 33 translated successfully.
# Comment 34 translated successfully.
# Comment 35 translated successfully.
# Comment 36 translated successfully.
# Comment 37 translated successfully.
# Comment 38 translated successfully.
# Comment 39 translated successfully.
# Comment 40 translated successfully.
# Comment 41 translated successfully.
# Comment 42 translated successfully.
# Comment 43 translated successfully.
# Comment 44 translated successfully.
# Comment 45 translated successfully.
TTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=auto&q=Good+job+its+time+for+him+to+pay+for+whatever+crimes+he+did+for+others.. (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000121E689E360>, 'Connection to translate.google.com timed out. (connect timeout=None)'))
# Comment 166 translated successfully.
# Comment 167 translated successfully.
# Comment 168 translated successfully.
# Comment 169 translated successfully.
# Translation failed for comment 170 (attempt 1): HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=auto&q=Bongbong+Marcos+++%0ANo+more+Marcos (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000121E67C5DC0>, 'Connection to translate.google.com timed out. (connect timeout=None)'))
# Comment 170 translated successfully.
# Comment 171 translated successfully.
# Comment 172 translated successfully.
# Comment 173 translated successfully.
# Comment 174 translated successfully.
# Comment 175 translated successfully.
# Comment 176 translated successfully.
# Comment 177 translated successfully.
# Comment 178 translated successfully.
# Comment 179 translated successfully.
# Translation failed for comment 180 after maximum retries.
# Translation failed for comment 181 (attempt 1): HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=auto&q=So+disappointed%21+The+only+man+who+truly+loves+the+Filipino+Citizens%21 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000121E68C7350>, 'Connection to translate.google.com timed out. (connect timeout=None)'))
# Comment 181 translated successfully.
# Comment 182 translated successfully.
# Comment 183 translated successfully.
# Comment 184 translated successfully.
# Translation failed for comment 185 (attempt 1): HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=auto&q=Long+waiting+is+over+%E2%80%A6+finally+%0AHe+deserves+it%E2%80%A6+justice+prevail+for+all++his+innocent+victims. (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000121E68C4A70>, 'Connection to translate.google.com timed out. (connect timeout=None)'))
# Comment 185 translated successfully.
# Translation failed for comment 186 (attempt 1): HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=auto&q=Ano+source+niyo%3F (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000121E63F38C0>, 'Connection to translate.google.com timed out. (connect timeout=None)'))
# Comment 186 translated successfully.
# Comment 187 translated successfully.
# Comment 188 translated successfully.
# Translation failed for comment 189 (attempt 1): HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=auto&q=Let+Justice+prevail%21+It%27s+time+to+prove+if+he+is+innocent.+Nakapiring+ang+mga+mata+ng+Katarungan.+Tutal+madalas+nya+sabihin+na+abogado+siya+at+Alam+nya+ang+batas.+So+be+it%21+Let+him+prove+him+self. (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000121E68A9550>, 'Connection to translate.google.com timed out. (connect timeout=None)'))
# Translation failed for comment 189 (attempt 2): HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=auto&q=Let+Justice+prevail%21+It%27s+time+to+prove+if+he+is+innocent.+Nakapiring+ang+mga+mata+ng+Katarungan.+Tutal+madalas+nya+sabihin+na+abogado+siya+at+Alam+nya+ang+batas.+So+be+it%21+Let+him+prove+him+self. (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000121E68C5D60>, 'Connection to translate.google.com timed out. (connect timeout=None)'))
# Translation failed for comment 189 (attempt 3): HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=auto&q=Let+Justice+prevail%21+It%27s+time+to+prove+if+he+is+innocent.+Nakapiring+ang+mga+mata+ng+Katarungan.+Tutal+madalas+nya+sabihin+na+abogado+siya+at+Alam+nya+ang+batas.+So+be+it%21+Let+him+prove+him+self. (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000121E68C64B0>, 'Connection to translate.google.com timed out. (connect timeout=None)'))
# Translation failed for comment 189 (attempt 4): HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=auto&q=Let+Justice+prevail%21+It%27s+time+to+prove+if+he+is+innocent.+Nakapiring+ang+mga+mata+ng+Katarungan.+Tutal+madalas+nya+sabihin+na+abogado+siya+at+Alam+nya+ang+batas.+So+be+it%21+Let+him+prove+him+self. (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000121E68C49E0>, 'Connection to translate.google.com timed out. (connect timeout=None)'))
# Comment 189 translated successfully.
# Comment 190 translated successfully.
# Comment 191 translated successfully.
# Comment 192 translated successfully.
# Comment 193 translated successfully.
# Comment 194 translated successfully.
# Comment 195 translated successfully.
# Translation failed for comment 196 (attempt 1): HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=auto&q=wala+lage+nyo+gibalita+tong+nahitabo+sa+u.s+kauban+c+bbm+ug+iyang+asawa%3F%3F%3F%3F (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000121E68C4A40>, 'Connection to translate.google.com timed out. (connect timeout=None)'))
# Comment 196 translated successfully.
# Comment 197 translated successfully.
# Comment 198 translated successfully.
# Comment 199 translated successfully.
# Comment 200 translated successfully.
# Comment 201 translated successfully.
# Comment 202 translated successfully.
# Comment 203 translated successfully.
# Comment 204 translated successfully.
# Comment 205 translated successfully.
# Comment 206 translated successfully.
# Comment 207 translated successfully.
# Comment 208 translated successfully.
# Translation failed for comment 209 after maximum retries.
# Comment 210 translated successfully.
# Comment 211 translated successfully.
# Comment 212 translated successfully.
# Comment 213 translated successfully.
# Comment 214 translated successfully.
# Comment 215 translated successfully.
# Comment 216 translated successfully.
# Comment 217 translated successfully.
# Comment 218 translated successfully.
# Comment 219 translated successfully.
# Translation failed for comment 220 (attempt 1): HTTPSConnectionPool(host='translate.google.com', port=443): Max retries exceeded with url: /m?tl=en&sl=auto&q=Lifespan+in+the+Philippines+is+exceptional+for+80+years+old.+What+you+will+do+about+make+Stories%3F+He+was+famous+already%2C+that%E2%80%99s+the+reason+he+want+to+be+arrested+because+he+will+die+soon (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x00000121E64CC860>, 'Connection to translate.google.com timed out. (connect timeout=None)'))
# Comment 220 translated successfully.
# Comment 221 translated successfully.
# Comment 222 translated successfully.
# Comment 223 translated successfully.
# Comment 224 translated successfully.
# Comment 225 translated successfully.
# Comment 226 translated successfully.
# Comment 227 translated successfully.
# Comment 228 translated successfully.
# Comment 229 translated successfully.
# Comment 230 translated successfully.
# Comment 231 translated successfully.
# Comment 232 translated successfully.
# Comment 233 translated successfully.
# Comment 234 translated successfully.
# Comment 235 translated successfully.
# Comment 236 translated successfully.
# Comment 237 translated successfully.
# Comment 238 translated successfully.
# Comment 239 translated successfully.
# Comment 240 translated successfully.
# Comment 241 translated successfully.
# Comment 242 translated successfully.
# Comment 243 translated successfully.
# Comment 244 translated successfully.
# Comment 245 translated successfully.
# Comment 246 translated successfully.
# Comment 247 translated successfully.
# Translation failed for comment 248 after maximum retries.
# Comment 249 translated successfully.
# Comment 250 translated successfully.
# Comment 251 translated successfully.
# Comment 252 translated successfully.
# Comment 253 translated successfully.
# Comment 254 translated successfully.
# Comment 471 translated successfully.
# Comment 472 translated successfully.
# Comment 473 translated successfully.
# Comment 474 translated successfully.
# Comment 475 translated successfully.
# Comment 476 translated successfully.
# Comment 477 translated successfully.
# Comment 478 translated successfully.
# Comment 479 translated successfully.
# Comment 480 translated successfully.
# Comment 481 translated successfully.
# Comment 482 translated successfully.
# Comment 483 translated successfully.
# Comment 484 translated successfully.
# Comment 485 translated successfully.
# Comment 486 translated successfully.
# Comment 487 translated successfully.
# Comment 488 translated successfully.
# Comment 489 translated successfully.
# Comment 490 translated successfully.
# Comment 491 translated successfully.
# Comment 492 translated successfully.
# Comment 493 translated successfully.
# Comment 494 translated successfully.
# Comment 495 translated successfully.
# Comment 496 translated successfully.
# Comment 497 translated successfully.
# Comment 498 translated successfully.
# Comment 499 translated successfully.
# Comment 500 translated successfully.
# Comment 501 translated successfully.
# Comment 502 translated successfully.
# Comment 503 translated successfully.
# Comment 504 translated successfully.
# Comment 505 translated successfully.
# Comment 506 translated successfully.
# Comment 507 translated successfully.
# Comment 508 translated successfully.
# Comment 509 translated successfully.
# Comment 510 translated successfully.
# Comment 511 translated successfully.
# Comment 512 translated successfully.
# Comment 513 translated successfully.
# Comment 514 translated successfully.
# Comment 515 translated successfully.
# Comment 516 translated successfully.
# Comment 517 translated successfully.
# Comment 518 translated successfully.
# Comment 519 translated successfully.
# Comment 520 translated successfully.
# Comment 521 translated successfully.
# Comment 522 translated successfully.
# Comment 523 translated successfully.
# Comment 524 translated successfully.
# Comment 525 translated successfully.
# Comment 526 translated successfully.
# Comment 527 translated successfully.
# Comment 528 translated successfully.
# Translation failed for comment 529 after maximum retries.
# Comment 530 translated successfully.
# Comment 531 translated successfully.
# Comment 532 translated successfully.
# Comment 533 translated successfully.
# Comment 534 translated successfully.
# Comment 535 translated successfully.
# Comment 536 translated successfully.
# Comment 537 translated successfully.
# Comment 538 translated successfully.
# Comment 539 translated successfully.
# Comment 540 translated successfully.
# Comment 541 translated successfully.
# Comment 542 translated successfully.
# Comment 543 translated successfully.
# Comment 544 translated successfully.

# %% [markdown]
# #### Deleting empty strings

# %%
df = df[df["commentsTranslation"].str.strip() != ""]

# %% [markdown]
# #### Saving the dataset to an excel file to manually correct translation errors

# %%
df.to_excel('trainingClean.xlsx')

# %% [markdown]
# ## New comments dataset

# %% [markdown]
# #### Reading the new comments dataset

# %%
newComments = pd.read_excel('newComments.xlsx')

# %% [markdown]
# #### Removing emojis and translating the comments to english

# %%
# Emoji removal regex (compiled once)
EMOJI_REGEX = re.compile(
    "["
    "\U0001F600-\U0001F64F"
    "\U0001F300-\U0001F5FF"
    "\U0001F680-\U0001F6FF"
    "\U0001F1E0-\U0001F1FF"
    "\U00002700-\U000027BF"
    "\U0001F900-\U0001F9FF"
    "\U0001FA70-\U0001FAFF"
    "\U00002600-\U000026FF"
    "]+", flags=re.UNICODE
)

# Helper to remove emojis
def remove_emojis(text):
    return EMOJI_REGEX.sub('', text)

translator = GoogleTranslator(source="auto", target="en")
commentsTranslation = []

for i, comment in enumerate(newComments["comment"], start=1):
    comment = remove_emojis(str(comment)) if isinstance(comment, str) else ""
    translated = ""

    for attempt in range(5):
        try:
            if comment:
                translated = translator.translate(comment)
                print(f"Comment {i} translated successfully.")
            break
        except Exception as e:
            print(f"Translation failed for comment {i} (attempt {attempt + 1}): {e}")
            time.sleep(3)

    if not translated:
        print(f"Translation failed for comment {i} after maximum retries.")

    commentsTranslation.append(translated)

newComments["commentsTranslation"] = commentsTranslation
# Out:
# Comment 1 translated successfully.
# Comment 2 translated successfully.
# Comment 3 translated successfully.
# Comment 4 translated successfully.
# Comment 5 translated successfully.
# Comment 6 translated successfully.
# Comment 7 translated successfully.
# Comment 8 translated successfully.
# Comment 9 translated successfully.
# Comment 10 translated successfully.
# Comment 11 translated successfully.
# Comment 12 translated successfully.
# Comment 13 translated successfully.
# Comment 14 translated successfully.
# Comment 15 translated successfully.
# Comment 16 translated successfully.
# Comment 17 translated successfully.
# Comment 18 translated successfully.
# Comment 19 translated successfully.
# Comment 20 translated successfully.
# Comment 21 translated successfully.
# Comment 22 translated successfully.
# Comment 23 translated successfully.
# Comment 24 translated successfully.
# Comment 25 translated successfully.
# Comment 26 translated successfully.
# Comment 27 translated successfully.
# Comment 28 translated successfully.
# Comment 29 translated successfully.
# Comment 30 translated successfully.
# Comment 31 translated successfully.
# Comment 32 translated successfully.
# Comment 33 translated successfully.
# Comment 34 translated successfully.
# Comment 35 translated successfully.
# Comment 36 translated successfully.
# Comment 37 translated successfully.
# Comment 38 translated successfully.
# Comment 39 translated successfully.
# Comment 40 translated successfully.
# Comment 41 translated successfully.
# Comment 42 translated successfully.
# Comment 43 translated successfully.
# Comment 44 translated successfully.
# Comment 45 translated successfully.
# Comment 46 translated successfully.
# Comment 47 translated successfully.
# Comment 48 translated successfully.
# Comment 49 translated successfully.
# Comment 50 translated successfully.
# Comment 51 translated successfully.
# Comment 52 translated successfully.
# Comment 53 translated successfully.
# Comment 54 translated successfully.
# Comment 55 translated successfully.
# Comment 56 translated successfully.
# Comment 57 translated successfully.
# Comment 58 translated successfully.
# Comment 59 translated successfully.
# Comment 60 translated successfully.
# Comment 61 translated successfully.
# Comment 62 translated successfully.
# Comment 63 translated successfully.
# Comment 64 translated successfully.
# Comment 65 translated successfully.
# Comment 66 translated successfully.
# Comment 67 translated successfully.
# Translation failed for comment 68 after maximum retries.
# Comment 69 translated successfully.
# Comment 70 translated successfully.
# Comment 71 translated successfully.
# Comment 72 translated successfully.
# Comment 73 translated successfully.
# Comment 74 translated successfully.
# Comment 75 translated successfully.
# Comment 76 translated successfully.
# Comment 77 translated successfully.
# Comment 78 translated successfully.
# Comment 79 translated successfully.
# Comment 80 translated successfully.
# Comment 81 translated successfully.
# Comment 82 translated successfully.
# Comment 83 translated successfully.
# Comment 84 translated successfully.
# Comment 85 translated successfully.
# Comment 86 translated successfully.
# Comment 87 translated successfully.
# Comment 88 translated successfully.
# Comment 89 translated successfully.
# Comment 522 translated successfully.
# Comment 523 translated successfully.
# Comment 524 translated successfully.
# Comment 525 translated successfully.
# Comment 526 translated successfully.
# Comment 527 translated successfully.
# Comment 528 translated successfully.
# Comment 529 translated successfully.
# Comment 530 translated successfully.
# Comment 531 translated successfully.
# Comment 532 translated successfully.
# Comment 533 translated successfully.
# Comment 534 translated successfully.
# Comment 535 translated successfully.
# Comment 536 translated successfully.
# Comment 537 translated successfully.
# Comment 538 translated successfully.
# Comment 539 translated successfully.
# Comment 540 translated successfully.
# Comment 541 translated successfully.
# Comment 542 translated successfully.
# Comment 543 translated successfully.
# Comment 544 translated successfully.
# Comment 545 translated successfully.

# %% [markdown]
# #### Deleting empty strings

# %%
newComments = newComments[newComments["commentsTranslation"].str.strip() != ""]

# %% [markdown]
# #### Saving the dataset to an excel file to manually correct translation errors

# %%
newComments.to_excel('newCommentsClean.xlsx')

# %% [markdown]
# # Model Training

# %% [markdown]
# #### Reading the cleaned training dataset

# %%
df = pd.read_excel('trainingClean.xlsx')

# %% [markdown]
# #### Importing the necessary libraries

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import nltk
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# #### Splitting the dataset for training and testing

# %%
X = df['commentsTranslation']
y = df['category']
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3, random_state = 101)

# %% [markdown]
# #### Lemmatization

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()

def custom_tokenizer(text):
    tokens = text.split()  # Basic tokenization (replace with more advanced if needed)
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in tokens]  # Lemmatization
    return lemmatized_tokens
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\Ivan
# [nltk_data]     Padilla\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\Ivan
# [nltk_data]     Padilla\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# #### Building the pipeline

# %%
pipeline = Pipeline([
    ('bow', CountVectorizer(tokenizer = custom_tokenizer, token_pattern = None)),
    ('tfidf', TfidfTransformer()),
    ('classifier', SVC())
])

# %% [markdown]
# #### Using the pipeline on the training dataset

# %%
pipeline.fit((X_train),(y_train))
# Out:
# Pipeline(steps=[('bow',
#                  CountVectorizer(token_pattern=None,
#                                  tokenizer=<function custom_tokenizer at 0x00000121F792EC00>)),
#                 ('tfidf', TfidfTransformer()), ('classifier', SVC())])

# %% [markdown]
# #### Using the trained model to predict the testing dataset

# %%
predictions = pipeline.predict(X_test)

# %% [markdown]
# #### Evaluating the model

# %%
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
# Out:
# [[66 12]
#  [12 70]]
#               precision    recall  f1-score   support
#
#            1       0.85      0.85      0.85        78
#            2       0.85      0.85      0.85        82
#
#     accuracy                           0.85       160
#    macro avg       0.85      0.85      0.85       160
# weighted avg       0.85      0.85      0.85       160

# %% [markdown]
# #### Applying Gridsearch to find the best parameters

# %%
param_grid = {
    'bow__ngram_range': [(0,1), (1,2), (1,3), (1,4)],
    'tfidf__sublinear_tf': [True, False],
    'classifier__C': [0.1,1,10,100, 1000],
    'classifier__kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
    'classifier__gamma': [1,0.1,0.01,0.001, 0.0001]
}

grid = GridSearchCV(pipeline,param_grid,refit=True, verbose = 2, scoring = 'accuracy')

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 800 candidates, totalling 4000 fits
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=0.1, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.2s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.1, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# [CV] END bow__ngram_range=(0, 1), classifier__C=1, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.0s
# ...
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.01, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.2s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.3s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.2s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.2s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=linear, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=poly, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=rbf, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=True; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.1s
# [CV] END bow__ngram_range=(1, 4), classifier__C=1000, classifier__gamma=0.0001, classifier__kernel=sigmoid, tfidf__sublinear_tf=False; total time=   0.1s
# GridSearchCV(estimator=Pipeline(steps=[('bow',
#                                         CountVectorizer(token_pattern=None,
#                                                         tokenizer=<function custom_tokenizer at 0x00000121F792EC00>)),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('classifier', SVC())]),
#              param_grid={'bow__ngram_range': [(0, 1), (1, 2), (1, 3), (1, 4)],
#                          'classifier__C': [0.1, 1, 10, 100, 1000],
#                          'classifier__gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'classifier__kernel': ['linear', 'poly', 'rbf',
#                                                 'sigmoid'],
#                          'tfidf__sublinear_tf': [True, False]},
#              scoring='accuracy', verbose=2)

# %% [markdown]
# #### Printing the best parameters, estimator and score

# %%
grid.best_params_
# Out:
# {'bow__ngram_range': (1, 3),
#  'classifier__C': 10,
#  'classifier__gamma': 1,
#  'classifier__kernel': 'rbf',
#  'tfidf__sublinear_tf': False}

# %%
grid.best_estimator_
# Out:
# Pipeline(steps=[('bow',
#                  CountVectorizer(ngram_range=(1, 3), token_pattern=None,
#                                  tokenizer=<function custom_tokenizer at 0x00000121F792EC00>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('classifier', SVC(C=10, gamma=1))])

# %%
grid.best_score_
# Out:
# 0.8901621621621623

# %% [markdown]
# #### Using the model with the best parameters to predict the testing dataset

# %%
grid_predict = grid.predict(X_test)

# %% [markdown]
# #### Evaluating the model with the best parameters

# %%
print(confusion_matrix(y_test, grid_predict))
print(classification_report(y_test, grid_predict))
# Out:
# [[68 10]
#  [13 69]]
#               precision    recall  f1-score   support
#
#            1       0.84      0.87      0.86        78
#            2       0.87      0.84      0.86        82
#
#     accuracy                           0.86       160
#    macro avg       0.86      0.86      0.86       160
# weighted avg       0.86      0.86      0.86       160

# %% [markdown]
# # Using the trained model on unseen data

# %% [markdown]
# #### Reading the dataset

# %%
df = pd.read_excel('newCommentsClean.xlsx')

# %% [markdown]
# #### Using the trained model on the new comments to predict sentiments

# %%
predictions = grid.predict(df['commentsTranslation'])

# %% [markdown]
# Creating a new column for the predictions, mapping prediction to a string, and getting the length of the original comments

# %%
df['predictedSentiment'] = predictions

# %%
df['categoricalSentiment'] = df['predictedSentiment'].map({1: 'Positive', 2:'Negative'})

# %%
df['commentLength'] = df['commentsTranslation'].apply(len)

# %%
df.head()
# Out:
#   userGender                                            comment  \
# 0     FEMALE                         No one is above the law...
# 1       MALE  Si BBM ang Presidente na kayang ibenta ang kap...
# 2     FEMALE  BTW WHATS THE NEWS ABOUT LISATANAS? WHY ARE YO...
# 3     FEMALE  JUSTICE SA VICTIMS NG LIBO2 NG EJK  @ MGA FAMI...
# 4     FEMALE  GMA AYUS AYUSIN MO YANG BALITA MO BAKA IKAW NA...
#
#                                  commentsTranslation  predictedSentiment  \
# 0                         No one is above the law...                   1
# 1  BBM is the president who can sell his fellow F...                   2
# 2  BTW WHATS THE NEWS ABOUT LISATANAS? WHY ARE YO...                   2
# 3  Justice to the thousands of victims of EJK and...                   1
# 4  GMA, fix your news properly or you might be th...                   2
#
#   categoricalSentiment  commentLength
# 0             Positive             26
# 1             Negative            118
# 2             Negative            109
# 3             Positive            108
# 4             Negative             70

# %% [markdown]
# # Analysis

# %% [markdown]
# #### Importing necessary plotting libraries

# %%
import plotly.io as pio
import plotly.express as px

# %% [markdown]
# #### Bar plot of predicted sentiment

# %%
categoricalSentiment = df.groupby(['categoricalSentiment']).size().reset_index(name = 'count')

# %%
categoricalSentiment
# Out:
#   categoricalSentiment  count
# 0             Negative    269
# 1             Positive    231

# %%
categoryFig = px.bar(categoricalSentiment, 
                     x = 'categoricalSentiment', 
                     y = 'count',  
                     labels = {'categoricalSentiment':'Predicted Sentiment', 'count':'Count'}, 
                     text_auto = True
                     )
categoryFig.show()
categoryFig.write_html('categoryFig.html', full_html = False, include_plotlyjs = 'cdn')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="badd215c-ad99-474e-9a46-73d028263950" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("badd215c-ad99-474e-9a46-73d028263950")) {                    Plotly.newPlot(                        "badd215c-ad99-474e-9a46-73d028263950",                        [{"hovertemplate":"Predicted Sentiment=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["Negative","Positive"],"xaxis":"x","y":{"dtype":"i2","bdata":"DQHnAA=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type ...

# %% [markdown]
# #### Bar plot of predicted sentiment broken down by user gender

# %%
categoricalSentimentGender = df.groupby(['userGender','categoricalSentiment']).size().reset_index(name = 'count')

# %%
categoricalSentimentGender
# Out:
#   userGender categoricalSentiment  count
# 0     FEMALE             Negative    138
# 1     FEMALE             Positive    118
# 2       MALE             Negative    131
# 3       MALE             Positive    113

# %%
categoryGenderFig = px.bar(categoricalSentimentGender, 
                     x = 'categoricalSentiment', 
                     y = 'count', 
                     color = 'userGender', 
                     labels = {'userGender':'Gender', 'categoricalSentiment':'Predicted Sentiment', 'count':'Count'}, 
                     text_auto = True
                     )
categoryGenderFig.show()
categoryGenderFig.write_html('categoryGenderFig.html', full_html = False, include_plotlyjs = 'cdn')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="bd0ef2a4-bdc2-467f-b3f2-ec205f80a0aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bd0ef2a4-bdc2-467f-b3f2-ec205f80a0aa")) {                    Plotly.newPlot(                        "bd0ef2a4-bdc2-467f-b3f2-ec205f80a0aa",                        [{"hovertemplate":"Gender=FEMALE\u003cbr\u003ePredicted Sentiment=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"FEMALE","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"FEMALE","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Negative","Positive"],"xaxis":"x","y":{"dtype":"i2","bdata":"igB2AA=="},"yaxis":"y","type":"bar"},{"hovertemplate":"Gender=MALE\u003cbr\u003ePredicted Sentiment=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"MALE","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"MALE","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Negative","Positive"],"xaxis":"x","y":{"dtype":"i2","bdata":"gwBxAA=="},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{ ...

# %% [markdown]
# #### Distribution of comment length

# %%
commentLength = px.histogram(df,
                             x = 'commentLength',
                             color = 'categoricalSentiment',
                             nbins = 100,
                             labels = {'count':'Count', 'commentLength':'Comment Length', 'categoricalSentiment': 'Sentiment'})
commentLength.show()
commentLength.write_html('commentLength.html', full_html = False, include_plotlyjs = 'cdn')
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="b0384b00-c7e2-43cd-a8b4-686a4f2be607" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("
ang imong rason sa paglingkod sa katungdanan, mokanaog ka sa katungdanan, dili nimo iapil ang mga inosenteng sibilyan sa imong mga kalihokan. Ang atong ekonomiya nangamatay, ug ang mga tigpamuhunan ug mga turista nagpanuko.\n\nIsip ordinaryo nga mga lungsuranon, kami adunay gahum nga manubag kaninyo sa wala pagtuman sa inyong mga katungdanan. Gigamit nimo ang imong mga posisyon alang sa personal nga interes. Makauulaw kung giunsa nimo paggamit ang pagsalig nga gihatag kanimo sa mga tawo nga nagpili kanimo. Kami masaligon nga imong tumanon ang imong mga katungdanan, apan hinoon, ang imong gihunahuna mao ang kung unsaon pagkuha og salapi. Kana nga kwarta dili imo, apan ato, ang mga tawo. Walay mga opisyal sa gobyerno kon wala kita.\n\nWala nimo gigamit ang pagsalig sa mga tawo, ug wala nimo gitahud ang Konstitusyon. Among gihangyo ang Department of Justice, ang Ombudsman, ug ang Korte Suprema nga moli ...

# %%
df[df['categoricalSentiment'] == 'Positive']['commentLength'].describe()
# Out:
# count     231.000000
# mean      147.246753
# std       187.086250
# min         9.000000
# 25%        41.000000
# 50%        86.000000
# 75%       157.000000
# max      1032.000000
# Name: commentLength, dtype: float64

# %%
df[df['categoricalSentiment'] == 'Negative']['commentLength'].describe()
# Out:
# count     269.000000
# mean      132.799257
# std       377.514274
# min         4.000000
# 25%        42.000000
# 50%        81.000000
# 75%       122.000000
# max      4693.000000
# Name: commentLength, dtype: float64

# %% [markdown]
# #### Topic Modeling using Latent Dirichlet Allocation and Non-negative Matrix Factorization

# %% [markdown]
# #### Importing necessary libraries

# %%
from sklearn.decomposition import LatentDirichletAllocation, NMF
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# #### Latent Dirichlet Allocation

# %%
pipeline = Pipeline([
    ('tf_vectorizer', CountVectorizer(max_df = 0.95, min_df = 2, max_features = 1000, stop_words="english")),
    ('lda', LatentDirichletAllocation(n_components = 10, max_iter = 5, learning_method = 'online', learning_offset = 50.0, random_state = 0))
])

# %%
pipeline.fit(df['commentsTranslation'])
# Out:
# Pipeline(steps=[('tf_vectorizer',
#                  CountVectorizer(max_df=0.95, max_features=1000, min_df=2,
#                                  stop_words='english')),
#                 ('lda',
#                  LatentDirichletAllocation(learning_method='online',
#                                            learning_offset=50.0, max_iter=5,
#                                            random_state=0))])

# %%
# Get feature names from CountVectorizer
feature_names = pipeline.named_steps['tf_vectorizer'].get_feature_names_out()

# Get the topic-word distribution matrix
lda_model = pipeline.named_steps['lda']
topics = lda_model.components_

# Display the top 10 words for each topic
for topic_idx, topic in enumerate(topics):
    top_words = [feature_names[i] for i in topic.argsort()[-10:]]
    print(f"Topic {topic_idx + 1}: {', '.join(top_words)}")
# Out:
# Topic 1: haist, paid, post, oh, fprrd, stand, late, bias, gma, media
# Topic 2: icc, accountable, held, roa, rodrigo, duterte, day, far, remember, bbm
# Topic 3: detained, high, president, right, lords, philippines, drugs, report, lady, drug
# Topic 4: just, ejk, served, law, country, duterte, philippines, victims, icc, justice
# Topic 5: update, report, lady, arrested, people, liza, duterte, marcos, gma, news
# Topic 6: paolo, hear, wanna, thing, karma, story, news, death, report, just
# Topic 7: won, love, best, arrest, like, time, god, tatay, digong, president
# Topic 8: torre, hiding, away, custodial, arrest, brought, state, warrant, court, icc
# Topic 9: resigned, high, police, leadership, disagree, forgiveness, ask, don, wish, arrest
# Topic 10: reporting, support, duterte, ug, ng, na, nga, mga, ang, sa

# %% [markdown]
# #### Non-negative matrix factorization

# %%
pipeline = Pipeline([
    ('tfidf_vectorizer', TfidfVectorizer(max_df = 0.95, min_df = 2, max_features = 1000, stop_words = "english")),
    ('nmf', NMF(n_components = 10, random_state = 1, init = 'nndsvda', beta_loss = "frobenius", alpha_W = 0.00005, alpha_H = 0.00005, l1_ratio = 1))
])

# %%
pipeline.fit(df['commentsTranslation'])
# Out:
# Pipeline(steps=[('tfidf_vectorizer',
#                  TfidfVectorizer(max_df=0.95, max_features=1000, min_df=2,
#                                  stop_words='english')),
#                 ('nmf',
#                  NMF(alpha_H=5e-05, alpha_W=5e-05, init='nndsvda', l1_ratio=1,
#                      n_components=10, random_state=1))])

# %%
# Get feature names from CountVectorizer
feature_names = pipeline.named_steps['tfidf_vectorizer'].get_feature_names_out()

# Get the topic-word distribution matrix
nmf_model = pipeline.named_steps['nmf']
topics = nmf_model.components_

# Display the top 10 words for each topic
for topic_idx, topic in enumerate(topics):
    top_words = [feature_names[i] for i in topic.argsort()[-10:]]
    print(f"Topic {topic_idx + 1}: {', '.join(top_words)}")
# Out:
# Topic 1: job, man, let, needs, great, ecstatic, long, yes, justice, served
# Topic 2: media, shut, reporting, tired, haha, marcos, liza, update, gma, news
# Topic 3: arrested, pnp, arrest, interpol, member, court, time, duterte, philippines, icc
# Topic 4: grateful, drug, thousands, praying, innocent, families, finally, justice, ejk, victims
# Topic 5: paolo, condition, detained, tantoco, fyang, stopped, america, la, lady, report
# Topic 6: prove, court, extent, prosecute, opportunity, harsh, innocent, let, rule, law
# Topic 7: deserved, thank, country, good, best, pray, forever, love, president, god
# Topic 8: warrant, thing, know, knows, happen, going, don, wait, right, just
# Topic 9: love, innocent, proven, cases, turned, protect, allah, ready, digong, tatay
# Topic 10: human, long, god, innocent, time, finally, truth, let, justice, prevail

# %% [markdown]
# # Hypothesis testing

# %% [markdown]
# **Null Hypothesis**: <br>
# No significant difference between positive and negative comments. <br>
# **Alternative Hypothesis:** <br>
# There is a significant difference between the positive and negative comments

# %%
import scipy.stats as stats
from scipy.stats import chi2

observed = [231, 269]
expected = [250, 250] 

alpha = 0.05
degrees_of_freedom = 1

critical_value = chi2.isf(alpha, degrees_of_freedom)
chi2_stat, p_value = stats.chisquare(observed, expected)

print(f"Chi-square Statistic: {chi2_stat}")
print(f"P-value: {p_value}")
print(f"Critical value: {critical_value}")
# Out:
# Chi-square Statistic: 2.888
# P-value: 0.08924164599420346
# Critical value: 3.8414588206941285

# %% [markdown]
# Since the chi-square statistic is less than the critical value and P-value (0.09) is greater than the alpha level 0.05, we have to accept the null hypothesis.
